# %%
# %matplotlib widget 
#requires package ipympl installed
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from scipy.optimize import curve_fit
from scipy.fft import fft, rfft,rfftfreq
np.set_printoptions(precision=4,threshold =9,suppress=True)  #Compact display.

cwd = os.getcwd()
cwd= os.path.split(os.getcwd())[0]

# %%
def quadratic(x,a,xc,c,d):
    return a*(x-xc)**2 + c*x+d

x = np.arange(0,10,0.01)
y = quadratic(x,-1,5,1,25)

fig,axes=plt.subplots(1,1,figsize=(5,5))
axes.scatter(x,y,color='black',s=15,ec='black',fc='none')
axes.set_xlim(0,10)
axes.set_ylim(0,26)
axes.set_xlabel('t',fontsize=14)
axes.set_ylabel('F')

import numpy as np
from scipy import integrate
  

  
# using scipy.integrate.cumtrapz() method
I2 = integrate.trapz(y, x)

I1 = np.sum(y)*0.01

print(I1,I2)
# Out:
# 216.61650000000003 216.56605050000002
